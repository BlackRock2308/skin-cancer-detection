# %% [markdown]
# # SKIN CANCER CLASSIFIER

# %%
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from skimage.io import imread
from skimage.color import rgb2grey
from sklearn.feature_extraction import image
from sklearn.cluster import KMeans
from skimage.filters import rank, threshold_otsu
from skimage.morphology import closing, square, disk
from skimage import exposure as hist, data, img_as_float
from skimage.segmentation import chan_vese
from skimage.feature import canny
from skimage.color import rgb2gray
from scipy import ndimage as ndi

# %%
mal_images = glob('./data/train/malignant/*')
ben_images = glob('./data/train/benign/*')
#Test
mal_images_test = glob('./data/test/malignant/*')
ben_images_test = glob('./data/test/benign/*')

# %%
len(mal_images)
# Out:
# 1197

# %%
len(ben_images)
# Out:
# 1440

# %%
mal_images_1 = glob('./data/train/malignant/*')[:5]
ben_images_1 = glob('./data/train/benign/*')[:5]

# %%
mal_images
# Out:
# ['./data/train/malignant\\10.jpg',
#  './data/train/malignant\\100.jpg',
#  './data/train/malignant\\1000.jpg',
#  './data/train/malignant\\1001.jpg',
#  './data/train/malignant\\1002.jpg',
#  './data/train/malignant\\1004.jpg',
#  './data/train/malignant\\1006.jpg',
#  './data/train/malignant\\1008.jpg',
#  './data/train/malignant\\101.jpg',
#  './data/train/malignant\\1010.jpg',
#  './data/train/malignant\\1011.jpg',
#  './data/train/malignant\\1013.jpg',
#  './data/train/malignant\\1014.jpg',
#  './data/train/malignant\\1015.jpg',
#  './data/train/malignant\\1016.jpg',
#  './data/train/malignant\\1017.jpg',
#  './data/train/malignant\\1018.jpg',
#  './data/train/malignant\\102.jpg',
#  './data/train/malignant\\1020.jpg',
#  './data/train/malignant\\1021.jpg',
#  './data/train/malignant\\1023.jpg',
#  './data/train/malignant\\1024.jpg',
#  './data/train/malignant\\1025.jpg',
#  './data/train/malignant\\1028.jpg',
#  './data/train/malignant\\1029.jpg',
#  './data/train/malignant\\103.jpg',
#  './data/train/malignant\\1030.jpg',
#  './data/train/malignant\\1031.jpg',
#  './data/train/malignant\\1032.jpg',
#  './data/train/malignant\\1033.jpg',
#  './data/train/malignant\\1034.jpg',
#  './data/train/malignant\\1035.jpg',
#  './data/train/malignant\\1036.jpg',
#  './data/train/malignant\\1039.jpg',
#  './data/train/malignant\\104.jpg',
#  './data/train/malignant\\1040.jpg',
#  './data/train/malignant\\1041.jpg',
#  './data/train/malignant\\1042.jpg',
#  './data/train/malignant\\1043.jpg',
#  './data/train/malignant\\1044.jpg',
#  './data/train/malignant\\1045.jpg',
#  './data/train/malignant\\1047.jpg',
#  './data/train/malignant\\1048.jpg',
#  './data/train/malignant\\105.jpg',
#  './data/train/malignant\\1050.jpg',
#  './data/train/malignant\\1051.jpg',
#  './data/train/malignant\\1052.jpg',
#  './data/train/malignant\\1053.jpg',
#  './data/train/malignant\\1054.jpg',
#  './data/train/malignant\\1055.jpg',
#  './data/train/malignant\\1057.jpg',
#  './data/train/malignant\\1059.jpg',
#  './data/train/malignant\\106.jpg',
#  './data/train/malignant\\1060.jpg',
#  './data/train/malignant\\1061.jpg',
#  './data/train/malignant\\1062.jpg',
#  './data/train/malignant\\1063.jpg',
#  './data/train/malignant\\1064.jpg',
#  './data/train/malignant\\1066.jpg',
#  './data/train/malignant\\1067.jpg',
#  './data/train/malignant\\1068.jpg',
#  './data/train/malignant\\1069.jpg',
#  './data/train/malignant\\107.jpg',
#  './data/train/malignant\\1070.jpg',
#  './data/train/malignant\\1071.jpg',
#  './data/train/malignant\\1072.jpg',
#  './data/train/malignant\\1073.jpg',
#  './data/train/malignant\\1075.jpg',
#  './data/train/malignant\\1076.jpg',
#  './data/train/malignant\\1077.jpg',
#  './data/train/malignant\\1078.jpg',
#  './data/train/malignant\\1079.jpg',
#  './data/train/malignant\\108.jpg',
#  './data/train/malignant\\1081.jpg',
#  './data/train/malignant\\1082.jpg',
#  './data/train/malignant\\1084.jpg',
#  './data/train/malignant\\1085.jpg',
#  './data/train/malignant\\1086.jpg',
#  './data/train/malignant\\1087.jpg',
#  './data/train/malignant\\1088.jpg',
#  './data/train/malignant\\109.jpg',
#  './data/train/malignant\\1090.jpg',
#  './data/train/malignant\\1092.jpg',
#  './data/train/malignant\\1093.jpg',
#  './data/train/malignant\\1095.jpg',
#  './data/train/malignant\\1096.jpg',
#  './data/train/malignant\\1097.jpg',
#  './data/train/malignant\\1098.jpg',
#  './data/train/malignant\\1099.jpg',
#  './data/train/malignant\\11.jpg',
#  './data/train/malignant\\1100.jpg',
#  './data/train/malignant\\1101.jpg',
#  './data/train/malignant\\1102.jpg',
#  './data/train/malignant\\1103.jpg',
#  './data/train/malignant\\1104.jpg',
#  './data/train/malignant\\1105.jpg',
#  './data/train/malignant\\1106.jpg',
#  './data/train/malignant\\1107.jpg',
#  './data/train/malignant\\1108.jpg',
#  './data/train/malignant\\1109.jpg',
#  './data/train/malignant\\111.jpg',
#  './data/train/malignant\\1110.jpg',
#  './data/train/malignant\\1111.jpg',
#  './data/train/malignant\\1114.jpg',
#  './data/train/malignant\\1115.jpg',
#  './data/train/malignant\\1116.jpg',
#  './data/train/malignant\\1117.jpg',
#  './data/train/malignant\\1118.jpg',
#  './data/train/malignant\\112.jpg',
#  './data/train/malignant\\1121.jpg',
#  './data/train/malignant\\1122.jpg',
#  './data/train/malignant\\1123.jpg',
#  './data/train/malignant\\1124.jpg',
#  './data/train/malignant\\1125.jpg',
#  './data/train/malignant\\1126.jpg',
#  './data/train/malignant\\1127.jpg',
#  './data/train/malignant\\1129.jpg',
#  './data/train/malignant\\113.jpg',
#  './data/train/malignant\\1130.jpg',
#  './data/train/malignant\\1131.jpg',
#  './data/train/malignant\\1132.jpg',
#  './data/train/malignant\\1133.jpg',
#  './data/train/malignant\\1134.jpg',
#  './data/train/malignant\\1136.jpg',
#  './data/train/malignant\\1137.jpg',
#  './data/train/malignant\\1138.jpg',
#  './data/train/malignant\\1139.jpg',
#  './data/train/malignant\\114.jpg',
#  './data/train/malignant\\1140.jpg',
#  './data/train/malignant\\1142.jpg',
#  './data/train/malignant\\1143.jpg',
#  './data/train/malignant\\1144.jpg',
#  './data/train/malignant\\1145.jpg',
#  './data/train/malignant\\1146.jpg',
#  './data/train/malignant\\1147.jpg',
#  './data/train/malignant\\1148.jpg',
#  './data/train/malignant\\1149.jpg',
#  './data/train/malignant\\115.jpg',
#  './data/train/malignant\\1152.jpg',
#  './data/train/malignant\\1153.jpg',
#  './data/train/malignant\\1154.jpg',
#  './data/train/malignant\\1157.jpg',
#  './data/train/malignant\\1158.jpg',
#  './data/train/malignant\\1159.jpg',
#  './data/train/malignant\\116.jpg',
#  './data/train/malignant\\1161.jpg',
#  './data/train/malignant\\1162.jpg',
#  './data/train/malignant\\1163.jpg',
#  './data/train/malignant\\1165.jpg',
#  './data/train/malignant\\1167.jpg',
#  './data/train/malignant\\1168.jpg',
#  './data/train/malignant\\1169.jpg',
#  './data/train/malignant\\117.jpg',
#  './data/train/malignant\\1171.jpg',
#  './data/train/malignant\\1172.jpg',
#  './data/train/malignant\\1174.jpg',
#  './data/train/malignant\\1175.jpg',
#  './data/train/malignant\\1177.jpg',
#  './data/train/malignant\\1178.jpg',
#  './data/train/malignant\\1179.jpg',
#  './data/train/malignant\\118.jpg',
#  './data/train/malignant\\1180.jpg',
#  './data/train/malignant\\1181.jpg',
#  './data/train/malignant\\1182.jpg',
#  './data/train/malignant\\1183.jpg',
#  './data/train/malignant\\1184.jpg',
#  './data/train/malignant\\1188.jpg',
#  './data/train/malignant\\119.jpg',
#  './data/train/malignant\\1190.jpg',
#  './data/train/malignant\\1191.jpg',
#  './data/train/malignant\\1192.jpg',
#  './data/train/malignant\\1193.jpg',
#  './data/train/malignant\\1195.jpg',
#  './data/train/malignant\\1196.jpg',
#  './data/train/malignant\\1199.jpg',
#  './data/train/malignant\\12.jpg',
#  './data/train/malignant\\120.jpg',
#  './data/train/malignant\\1200.jpg',
#  './data/train/malignant\\1201.jpg',
#  './data/train/malignant\\1202.jpg',
#  './data/train/malignant\\1203.jpg',
#  './data/train/malignant\\1204.jpg',
#  './data/train/malignant\\1205.jpg',
#  './data/train/malignant\\1206.jpg',
#  './data/train/malignant\\1207.jpg',
#  './data/train/malignant\\1208.jpg',
#  './data/train/malignant\\1209.jpg',
#  './data/train/malignant\\121.jpg',
#  './data/train/malignant\\1210.jpg',
#  './data/train/malignant\\1212.jpg',
#  './data/train/malignant\\1213.jpg',
#  './data/train/malignant\\1214.jpg',
#  './data/train/malignant\\1217.jpg',
#  './data/train/malignant\\1219.jpg',
#  './data/train/malignant\\122.jpg',
#  './data/train/malignant\\1222.jpg',
#  './data/train/malignant\\1223.jpg',
#  './data/train/malignant\\1224.jpg',
#  './data/train/malignant\\1225.jpg',
#  './data/train/malignant\\1226.jpg',
#  './data/train/malignant\\123.jpg',
#  './data/train/malignant\\1230.jpg',
#  './data/train/malignant\\1231.jpg',
#  './data/train/malignant\\1232.jpg',
#  './data/train/malignant\\1233.jpg',
#  './data/train/malignant\\1235.jpg',
#  './data/train/malignant\\1236.jpg',
#  './data/train/malignant\\1237.jpg',
#  './data/train/malignant\\1239.jpg',
#  './data/train/malignant\\124.jpg',
#  './data/train/malignant\\1240.jpg',
#  './data/train/malignant\\1241.jpg',
#  './data/train/malignant\\1243.jpg',
#  './data/train/malignant\\1244.jpg',
#  './data/train/malignant\\1245.jpg',
#  './data/train/malignant\\1246.jpg',
#  './data/train/malignant\\1247.jpg',
#  './data/train/malignant\\1248.jpg',
#  './data/train/malignant\\1249.jpg',
#  './data/train/malignant\\125.jpg',
#  './data/train/malignant\\1250.jpg',
#  './data/train/malignant\\1252.jpg',
#  './data/train/malignant\\1253.jpg',
#  './data/train/malignant\\1255.jpg',
#  './data/train/malignant\\1257.jpg',
#  './data/train/malignant\\1258.jpg',
#  './data/train/malignant\\1259.jpg',
#  './data/train/malignant\\126.jpg',
#  './data/train/malignant\\1260.jpg',
#  './data/train/malignant\\1261.jpg',
#  './data/train/malignant\\1263.jpg',
#  './data/train/malignant\\1264.jpg',
#  './data/train/malignant\\1265.jpg',
#  './data/train/malignant\\1269.jpg',
#  './data/train/malignant\\127.jpg',
#  './data/train/malignant\\1270.jpg',
#  './data/train/malignant\\1271.jpg',
#  './data/train/malignant\\1272.jpg',
#  './data/train/malignant\\1273.jpg',
#  './data/train/malignant\\1274.jpg',
#  './data/train/malignant\\1275.jpg',
#  './data/train/malignant\\1276.jpg',
#  './data/train/malignant\\1277.jpg',
#  './data/train/malignant\\1278.jpg',
#  './data/train/malignant\\1279.jpg',
#  './data/train/malignant\\128.jpg',
#  './data/train/malignant\\1281.jpg',
#  './data/train/malignant\\1282.jpg',
#  './data/train/malignant\\1283.jpg',
#  './data/train/malignant\\1284.jpg',
#  './data/train/malignant\\1285.jpg',
#  './data/train/malignant\\1287.jpg',
#  './data/train/malignant\\1288.jpg',
#  './data/train/malignant\\1290.jpg',
#  './data/train/malignant\\1291.jpg',
#  './data/train/malignant\\1293.jpg',
#  './data/train/malignant\\1294.jpg',
#  './data/train/malignant\\1296.jpg',
#  './data/train/malignant\\1298.jpg',
#  './data/train/malignant\\1299.jpg',
#  './data/train/malignant\\130.jpg',
#  './data/train/malignant\\1301.jpg',
#  './data/train/malignant\\1302.jpg',
#  './data/train/malignant\\1303.jpg',
#  './data/train/malignant\\1304.jpg',
#  './data/train/malignant\\1305.jpg',
#  './data/train/malignant\\1306.jpg',
#  './data/train/malignant\\1307.jpg',
#  './data/train/malignant\\1308.jpg',
#  './data/train/malignant\\1309.jpg',
#  './data/train/malignant\\131.jpg',
#  './data/train/malignant\\1311.jpg',
#  './data/train/malignant\\1312.jpg',
#  './data/train/malignant\\1313.jpg',
#  './data/train/malignant\\1314.jpg',
#  './data/train/malignant\\1315.jpg',
#  './data/train/malignant\\1316.jpg',
#  './data/train/malignant\\1317.jpg',
#  './data/train/malignant\\1318.jpg',
#  './data/train/malignant\\1319.jpg',
#  './data/train/malignant\\132.jpg',
#  './data/train/malignant\\1321.jpg',
#  './data/train/malignant\\1323.jpg',
#  './data/train/malignant\\1324.jpg',
#  './data/train/malignant\\1325.jpg',
#  './data/train/malignant\\1326.jpg',
#  './data/train/malignant\\1327.jpg',
#  './data/train/malignant\\1328.jpg',
#  './data/train/malignant\\1329.jpg',
#  './data/train/malignant\\133.jpg',
#  './data/train/malignant\\1331.jpg',
#  './data/train/malignant\\1332.jpg',
#  './data/train/malignant\\1334.jpg',
#  './data/train/malignant\\1335.jpg',
#  './data/train/malignant\\1337.jpg',
#  './data/train/malignant\\1338.jpg',
#  './data/train/malignant\\134.jpg',
#  './data/train/malignant\\1340.jpg',
#  './data/train/malignant\\1341.jpg',
#  './data/train/malignant\\1343.jpg',
#  './data/train/malignant\\1344.jpg',
#  './data/train/malignant\\1345.jpg',
#  './data/train/malignant\\1346.jpg',
#  './data/train/malignant\\1348.jpg',
#  './data/train/malignant\\1349.jpg',
#  './data/train/malignant\\135.jpg',
#  './data/train/malignant\\1350.jpg',
#  './data/train/malignant\\1351.jpg',
#  './data/train/malignant\\1352.jpg',
#  './data/train/malignant\\1353.jpg',
#  './data/train/malignant\\1356.jpg',
#  './data/train/malignant\\1357.jpg',
#  './data/train/malignant\\136.jpg',
#  './data/train/malignant\\1360.jpg',
#  './data/train/malignant\\1361.jpg',
#  './data/train/malignant\\1362.jpg',
#  './data/train/malignant\\1363.jpg',
#  './data/train/malignant\\1365.jpg',
#  './data/train/malignant\\1367.jpg',
#  './data/train/malignant\\1368.jpg',
#  './data/train/malignant\\1369.jpg',
#  './data/train/malignant\\137.jpg',
#  './data/train/malignant\\1371.jpg',
#  './data/train/malignant\\1372.jpg',
#  './data/train/malignant\\1373.jpg',
#  './data/train/malignant\\1375.jpg',
#  './data/train/malignant\\1376.jpg',
#  './data/train/malignant\\1377.jpg',
#  './data/train/malignant\\138.jpg',
#  './data/train/malignant\\1381.jpg',
#  './data/train/malignant\\1384.jpg',
#  './data/train/malignant\\1385.jpg',
#  './data/train/malignant\\1386.jpg',
#  './data/train/malignant\\1387.jpg',
#  './data/train/malignant\\1388.jpg',
#  './data/train/malignant\\1389.jpg',
#  './data/train/malignant\\1390.jpg',
#  './data/train/malignant\\1391.jpg',
#  './data/train/malignant\\1392.jpg',
#  './data/train/malignant\\1393.jpg',
#  './data/train/malignant\\1394.jpg',
#  './data/train/malignant\\1396.jpg',
#  './data/train/malignant\\1397.jpg',
#  './data/train/malignant\\1398.jpg',
#  './data/train/malignant\\1399.jpg',
#  './data/train/malignant\\14.jpg',
#  './data/train/malignant\\140.jpg',
#  './data/train/malignant\\1400.jpg',
#  './data/train/malignant\\1403.jpg',
#  './data/train/malignant\\1404.jpg',
#  './data/train/malignant\\1405.jpg',
#  './data/train/malignant\\1406.jpg',
#  './data/train/malignant\\1407.jpg',
#  './data/train/malignant\\1408.jpg',
#  './data/train/malignant\\1409.jpg',
#  './data/train/malignant\\141.jpg',
#  './data/train/malignant\\1410.jpg',
#  './data/train/malignant\\1411.jpg',
#  './data/train/malignant\\1412.jpg',
#  './data/train/malignant\\1413.jpg',
#  './data/train/malignant\\1414.jpg',
#  './data/train/malignant\\1415.jpg',
#  './data/train/malignant\\1416.jpg',
#  './data/train/malignant\\1418.jpg',
#  './data/train/malignant\\1419.jpg',
#  './data/train/malignant\\142.jpg',
#  './data/train/malignant\\1420.jpg',
#  './data/train/malignant\\1421.jpg',
#  './data/train/malignant\\1423.jpg',
#  './data/train/malignant\\1424.jpg',
#  './data/train/malignant\\1426.jpg',
#  './data/train/malignant\\1428.jpg',
#  './data/train/malignant\\1429.jpg',
#  './data/train/malignant\\143.jpg',
#  './data/train/malignant\\1431.jpg',
#  './data/train/malignant\\1432.jpg',
#  './data/train/malignant\\1433.jpg',
#  './data/train/malignant\\1434.jpg',
#  './data/train/malignant\\1435.jpg',
#  './data/train/malignant\\1437.jpg',
#  './data/train/malignant\\1439.jpg',
#  './data/train/malignant\\144.jpg',
#  './data/train/malignant\\1440.jpg',
#  './data/train/malignant\\1441.jpg',
#  './data/train/malignant\\1442.jpg',
#  './data/train/malignant\\1444.jpg',
#  './data/train/malignant\\1445.jpg',
#  './data/train/malignant\\1446.jpg',
#  './data/train/malignant\\1448.jpg',
#  './data/train/malignant\\1449.jpg',
#  './data/train/malignant\\145.jpg',
#  './data/train/malignant\\1450.jpg',
#  './data/train/malignant\\1452.jpg',
#  './data/train/malignant\\1453.jpg',
#  './data/train/malignant\\1454.jpg',
#  './data/train/malignant\\1455.jpg',
#  './data/train/malignant\\1456.jpg',
#  './data/train/malignant\\1457.jpg',
#  './data/train/malignant\\1458.jpg',
#  './data/train/malignant\\1459.jpg',
#  './data/train/malignant\\146.jpg',
#  './data/train/malignant\\1460.jpg',
#  './data/train/malignant\\1462.jpg',
#  './data/train/malignant\\1463.jpg',
#  './data/train/malignant\\1465.jpg',
#  './data/train/malignant\\1466.jpg',
#  './data/train/malignant\\1467.jpg',
#  './data/train/malignant\\1468.jpg',
#  './data/train/malignant\\1469.jpg',
#  './data/train/malignant\\147.jpg',
#  './data/train/malignant\\1470.jpg',
#  './data/train/malignant\\1471.jpg',
#  './data/train/malignant\\1472.jpg',
#  './data/train/malignant\\1473.jpg',
#  './data/train/malignant\\1474.jpg',
#  './data/train/malignant\\1475.jpg',
#  './data/train/malignant\\1476.jpg',
#  './data/train/malignant\\1477.jpg',
#  './data/train/malignant\\1478.jpg',
#  './data/train/malignant\\1479.jpg',
#  './data/train/malignant\\148.jpg',
#  './data/train/malignant\\1480.jpg',
#  './data/train/malignant\\1481.jpg',
#  './data/train/malignant\\1482.jpg',
#  './data/train/malignant\\1483.jpg',
#  './data/train/malignant\\1485.jpg',
#  './data/train/malignant\\1486.jpg',
#  './data/train/malignant\\1487.jpg',
#  './data/train/malignant\\1488.jpg',
#  './data/train/malignant\\149.jpg',
#  './data/train/malignant\\1490.jpg',
#  './data/train/malignant\\1491.jpg',
#  './data/train/malignant\\1492.jpg',
#  './data/train/malignant\\1493.jpg',
#  './data/train/malignant\\1494.jpg',
#  './data/train/malignant\\1496.jpg',
#  './data/train/malignant\\1497.jpg',
#  './data/train/malignant\\1498.jpg',
#  './data/train/malignant\\15.jpg',
#  './data/train/malignant\\150.jpg',
#  './data/train/malignant\\1500.jpg',
#  './data/train/malignant\\151.jpg',
#  './data/train/malignant\\152.jpg',
#  './data/train/malignant\\153.jpg',
#  './data/train/malignant\\154.jpg',
#  './data/train/malignant\\155.jpg',
#  './data/train/malignant\\157.jpg',
#  './data/train/malignant\\158.jpg',
#  './data/train/malignant\\159.jpg',
#  './data/train/malignant\\16.jpg',
#  './data/train/malignant\\160.jpg',
#  './data/train/malignant\\162.jpg',
#  './data/train/malignant\\163.jpg',
#  './data/train/malignant\\164.jpg',
#  './data/train/malignant\\165.jpg',
#  './data/train/malignant\\166.jpg',
#  './data/train/malignant\\167.jpg',
#  './data/train/malignant\\168.jpg',
#  './data/train/malignant\\169.jpg',
#  './data/train/malignant\\170.jpg',
#  './data/train/malignant\\171.jpg',
#  './data/train/malignant\\172.jpg',
#  './data/train/malignant\\174.jpg',
#  './data/train/malignant\\175.jpg',
#  './data/train/malignant\\176.jpg',
#  './data/train/malignant\\177.jpg',
#  './data/train/malignant\\178.jpg',
#  './data/train/malignant\\18.jpg',
#  './data/train/malignant\\180.jpg',
#  './data/train/malignant\\181.jpg',
#  './data/train/malignant\\183.jpg',
#  './data/train/malignant\\187.jpg',
#  './data/train/malignant\\188.jpg',
#  './data/train/malignant\\189.jpg',
#  './data/train/malignant\\19.jpg',
#  './data/train/malignant\\191.jpg',
#  './data/train/malignant\\192.jpg',
#  './data/train/malignant\\194.jpg',
#  './data/train/malignant\\197.jpg',
#  './data/train/malignant\\198.jpg',
#  './data/train/malignant\\199.jpg',
#  './data/train/malignant\\2.jpg',
#  './data/train/malignant\\20.jpg',
#  './data/train/malignant\\201.jpg',
#  './data/train/malignant\\202.jpg',
#  './data/train/malignant\\203.jpg',
#  './data/train/malignant\\204.jpg',
#  './data/train/malignant\\205.jpg',
#  './data/train/malignant\\206.jpg',
#  './data/train/malignant\\207.jpg',
#  './data/train/malignant\\209.jpg',
#  './data/train/malignant\\21.jpg',
#  './data/train/malignant\\210.jpg',
#  './data/train/malignant\\211.jpg',
#  './data/train/malignant\\212.jpg',
#  './data/train/malignant\\213.jpg',
#  './data/train/malignant\\214.jpg',
#  './data/train/malignant\\215.jpg',
#  './data/train/malignant\\216.jpg',
#  './data/train/malignant\\217.jpg',
#  './data/train/malignant\\218.jpg',
#  './data/train/malignant\\219.jpg',
#  './data/train/malignant\\22.jpg',
#  './data/train/malignant\\220.jpg',
#  './data/train/malignant\\221.jpg',
#  './data/train/malignant\\222.jpg',
#  './data/train/malignant\\223.jpg',
#  './data/train/malignant\\224.jpg',
#  './data/train/malignant\\225.jpg',
#  './data/train/malignant\\226.jpg',
#  './data/train/malignant\\227.jpg',
#  './data/train/malignant\\228.jpg',
#  './data/train/malignant\\229.jpg',
#  './data/train/malignant\\23.jpg',
#  './data/train/malignant\\230.jpg',
#  './data/train/malignant\\233.jpg',
#  './data/train/malignant\\234.jpg',
#  './data/train/malignant\\235.jpg',
#  './data/train/malignant\\236.jpg',
#  './data/train/malignant\\239.jpg',
#  './data/train/malignant\\240.jpg',
#  './data/train/malignant\\241.jpg',
#  './data/train/malignant\\242.jpg',
#  './data/train/malignant\\243.jpg',
#  './data/train/malignant\\244.jpg',
#  './data/train/malignant\\245.jpg',
#  './data/train/malignant\\246.jpg',
#  './data/train/malignant\\248.jpg',
#  './data/train/malignant\\249.jpg',
#  './data/train/malignant\\25.jpg',
#  './data/train/malignant\\250.jpg',
#  './data/train/malignant\\251.jpg',
#  './data/train/malignant\\252.jpg',
#  './data/train/malignant\\253.jpg',
#  './data/train/malignant\\254.jpg',
#  './data/train/malignant\\255.jpg',
#  './data/train/malignant\\259.jpg',
#  './data/train/malignant\\26.jpg',
#  './data/train/malignant\\261.jpg',
#  './data/train/malignant\\262.jpg',
#  './data/train/malignant\\263.jpg',
#  './data/train/malignant\\264.jpg',
#  './data/train/malignant\\265.jpg',
#  './data/train/malignant\\266.jpg',
#  './data/train/malignant\\267.jpg',
#  './data/train/malignant\\268.jpg',
#  './data/train/malignant\\269.jpg',
#  './data/train/malignant\\27.jpg',
#  './data/train/malignant\\270.jpg',
#  './data/train/malignant\\271.jpg',
#  './data/train/malignant\\272.jpg',
#  './data/train/malignant\\273.jpg',
#  './data/train/malignant\\274.jpg',
#  './data/train/malignant\\277.jpg',
#  './data/train/malignant\\278.jpg',
#  './data/train/malignant\\279.jpg',
#  './data/train/malignant\\28.jpg',
#  './data/train/malignant\\280.jpg',
#  './data/train/malignant\\281.jpg',
#  './data/train/malignant\\282.jpg',
#  './data/train/malignant\\283.jpg',
#  './data/train/malignant\\284.jpg',
#  './data/train/malignant\\285.jpg',
#  './data/train/malignant\\286.jpg',
#  './data/train/malignant\\287.jpg',
#  './data/train/malignant\\288.jpg',
#  './data/train/malignant\\289.jpg',
#  './data/train/malignant\\29.jpg',
#  './data/train/malignant\\290.jpg',
#  './data/train/malignant\\291.jpg',
#  './data/train/malignant\\292.jpg',
#  './data/train/malignant\\293.jpg',
#  './data/train/malignant\\294.jpg',
#  './data/train/malignant\\295.jpg',
#  './data/train/malignant\\296.jpg',
#  './data/train/malignant\\297.jpg',
#  './data/train/malignant\\298.jpg',
#  './data/train/malignant\\299.jpg',
#  './data/train/malignant\\30.jpg',
#  './data/train/malignant\\300.jpg',
#  './data/train/malignant\\301.jpg',
#  './data/train/malignant\\302.jpg',
#  './data/train/malignant\\304.jpg',
#  './data/train/malignant\\305.jpg',
#  './data/train/malignant\\306.jpg',
#  './data/train/malignant\\308.jpg',
#  './data/train/malignant\\309.jpg',
#  './data/train/malignant\\31.jpg',
#  './data/train/malignant\\311.jpg',
#  './data/train/malignant\\312.jpg',
#  './data/train/malignant\\313.jpg',
#  './data/train/malignant\\314.jpg',
#  './data/train/malignant\\315.jpg',
#  './data/train/malignant\\316.jpg',
#  './data/train/malignant\\319.jpg',
#  './data/train/malignant\\32.jpg',
#  './data/train/malignant\\320.jpg',
#  './data/train/malignant\\321.jpg',
#  './data/train/malignant\\323.jpg',
#  './data/train/malignant\\324.jpg',
#  './data/train/malignant\\325.jpg',
#  './data/train/malignant\\326.jpg',
#  './data/train/malignant\\327.jpg',
#  './data/train/malignant\\328.jpg',
#  './data/train/malignant\\329.jpg',
#  './data/train/malignant\\330.jpg',
#  './data/train/malignant\\331.jpg',
#  './data/train/malignant\\332.jpg',
#  './data/train/malignant\\333.jpg',
#  './data/train/malignant\\334.jpg',
#  './data/train/malignant\\335.jpg',
#  './data/train/malignant\\336.jpg',
#  './data/train/malignant\\337.jpg',
#  './data/train/malignant\\339.jpg',
#  './data/train/malignant\\34.jpg',
#  './data/train/malignant\\340.jpg',
#  './data/train/malignant\\341.jpg',
#  './data/train/malignant\\344.jpg',
#  './data/train/malignant\\345.jpg',
#  './data/train/malignant\\346.jpg',
#  './data/train/malignant\\347.jpg',
#  './data/train/malignant\\349.jpg',
#  './data/train/malignant\\35.jpg',
#  './data/train/malignant\\350.jpg',
#  './data/train/malignant\\351.jpg',
#  './data/train/malignant\\352.jpg',
#  './data/train/malignant\\353.jpg',
#  './data/train/malignant\\354.jpg',
#  './data/train/malignant\\357.jpg',
#  './data/train/malignant\\358.jpg',
#  './data/train/malignant\\359.jpg',
#  './data/train/malignant\\36.jpg',
#  './data/train/malignant\\361.jpg',
#  './data/train/malignant\\362.jpg',
#  './data/train/malignant\\363.jpg',
#  './data/train/malignant\\365.jpg',
#  './data/train/malignant\\366.jpg',
#  './data/train/malignant\\367.jpg',
#  './data/train/malignant\\368.jpg',
#  './data/train/malignant\\369.jpg',
#  './data/train/malignant\\37.jpg',
#  './data/train/malignant\\370.jpg',
#  './data/train/malignant\\371.jpg',
#  './data/train/malignant\\372.jpg',
#  './data/train/malignant\\373.jpg',
#  './data/train/malignant\\374.jpg',
#  './data/train/malignant\\376.jpg',
#  './data/train/malignant\\377.jpg',
#  './data/train/malignant\\378.jpg',
#  './data/train/malignant\\379.jpg',
#  './data/train/malignant\\38.jpg',
#  './data/train/malignant\\380.jpg',
#  './data/train/malignant\\383.jpg',
#  './data/train/malignant\\385.jpg',
#  './data/train/malignant\\386.jpg',
#  './data/train/malignant\\387.jpg',
#  './data/train/malignant\\388.jpg',
#  './data/train/malignant\\391.jpg',
#  './data/train/malignant\\392.jpg',
#  './data/train/malignant\\393.jpg',
#  './data/train/malignant\\395.jpg',
#  './data/train/malignant\\396.jpg',
#  './data/train/malignant\\397.jpg',
#  './data/train/malignant\\398.jpg',
#  './data/train/malignant\\40.jpg',
#  './data/train/malignant\\400.jpg',
#  './data/train/malignant\\401.jpg',
#  './data/train/malignant\\403.jpg',
#  './data/train/malignant\\404.jpg',
#  './data/train/malignant\\406.jpg',
#  './data/train/malignant\\408.jpg',
#  './data/train/malignant\\41.jpg',
#  './data/train/malignant\\410.jpg',
#  './data/train/malignant\\411.jpg',
#  './data/train/malignant\\412.jpg',
#  './data/train/malignant\\413.jpg',
#  './data/train/malignant\\414.jpg',
#  './data/train/malignant\\415.jpg',
#  './data/train/malignant\\416.jpg',
#  './data/train/malignant\\417.jpg',
#  './data/train/malignant\\418.jpg',
#  './data/train/malignant\\42.jpg',
#  './data/train/malignant\\420.jpg',
#  './data/train/malignant\\422.jpg',
#  './data/train/malignant\\423.jpg',
#  './data/train/malignant\\425.jpg',
#  './data/train/malignant\\427.jpg',
#  './data/train/malignant\\429.jpg',
#  './data/train/malignant\\43.jpg',
#  './data/train/malignant\\431.jpg',
#  './data/train/malignant\\432.jpg',
#  './data/train/malignant\\433.jpg',
#  './data/train/malignant\\434.jpg',
#  './data/train/malignant\\435.jpg',
#  './data/train/malignant\\438.jpg',
#  './data/train/malignant\\439.jpg',
#  './data/train/malignant\\440.jpg',
#  './data/train/malignant\\441.jpg',
#  './data/train/malignant\\442.jpg',
#  './data/train/malignant\\443.jpg',
#  './data/train/malignant\\444.jpg',
#  './data/train/malignant\\446.jpg',
#  './data/train/malignant\\447.jpg',
#  './data/train/malignant\\448.jpg',
#  './data/train/malignant\\449.jpg',
#  './data/train/malignant\\45.jpg',
#  './data/train/malignant\\451.jpg',
#  './data/train/malignant\\452.jpg',
#  './data/train/malignant\\453.jpg',
#  './data/train/malignant\\454.jpg',
#  './data/train/malignant\\455.jpg',
#  './data/train/malignant\\456.jpg',
#  './data/train/malignant\\457.jpg',
#  './data/train/malignant\\458.jpg',
#  './data/train/malignant\\460.jpg',
#  './data/train/malignant\\461.jpg',
#  './data/train/malignant\\462.jpg',
#  './data/train/malignant\\464.jpg',
#  './data/train/malignant\\465.jpg',
#  './data/train/malignant\\466.jpg',
#  './data/train/malignant\\467.jpg',
#  './data/train/malignant\\468.jpg',
#  './data/train/malignant\\469.jpg',
#  './data/train/malignant\\47.jpg',
#  './data/train/malignant\\470.jpg',
#  './data/train/malignant\\471.jpg',
#  './data/train/malignant\\472.jpg',
#  './data/train/malignant\\473.jpg',
#  './data/train/malignant\\475.jpg',
#  './data/train/malignant\\476.jpg',
#  './data/train/malignant\\477.jpg',
#  './data/train/malignant\\478.jpg',
#  './data/train/malignant\\48.jpg',
#  './data/train/malignant\\480.jpg',
#  './data/train/malignant\\481.jpg',
#  './data/train/malignant\\482.jpg',
#  './data/train/malignant\\484.jpg',
#  './data/train/malignant\\485.jpg',
#  './data/train/malignant\\486.jpg',
#  './data/train/malignant\\487.jpg',
#  './data/train/malignant\\488.jpg',
#  './data/train/malignant\\489.jpg',
#  './data/train/malignant\\49.jpg',
#  './data/train/malignant\\490.jpg',
#  './data/train/malignant\\491.jpg',
#  './data/train/malignant\\492.jpg',
#  './data/train/malignant\\493.jpg',
#  './data/train/malignant\\494.jpg',
#  './data/train/malignant\\495.jpg',
#  './data/train/malignant\\496.jpg',
#  './data/train/malignant\\497.jpg',
#  './data/train/malignant\\498.jpg',
#  './data/train/malignant\\499.jpg',
#  './data/train/malignant\\5.jpg',
#  './data/train/malignant\\50.jpg',
#  './data/train/malignant\\500.jpg',
#  './data/train/malignant\\502.jpg',
#  './data/train/malignant\\503.jpg',
#  './data/train/malignant\\505.jpg',
#  './data/train/malignant\\506.jpg',
#  './data/train/malignant\\509.jpg',
#  './data/train/malignant\\51.jpg',
#  './data/train/malignant\\510.jpg',
#  './data/train/malignant\\512.jpg',
#  './data/train/malignant\\513.jpg',
#  './data/train/malignant\\514.jpg',
#  './data/train/malignant\\515.jpg',
#  './data/train/malignant\\516.jpg',
#  './data/train/malignant\\517.jpg',
#  './data/train/malignant\\518.jpg',
#  './data/train/malignant\\520.jpg',
#  './data/train/malignant\\521.jpg',
#  './data/train/malignant\\522.jpg',
#  './data/train/malignant\\523.jpg',
#  './data/train/malignant\\524.jpg',
#  './data/train/malignant\\525.jpg',
#  './data/train/malignant\\526.jpg',
#  './data/train/malignant\\527.jpg',
#  './data/train/malignant\\529.jpg',
#  './data/train/malignant\\53.jpg',
#  './data/train/malignant\\530.jpg',
#  './data/train/malignant\\531.jpg',
#  './data/train/malignant\\532.jpg',
#  './data/train/malignant\\533.jpg',
#  './data/train/malignant\\534.jpg',
#  './data/train/malignant\\535.jpg',
#  './data/train/malignant\\537.jpg',
#  './data/train/malignant\\538.jpg',
#  './data/train/malignant\\539.jpg',
#  './data/train/malignant\\540.jpg',
#  './data/train/malignant\\541.jpg',
#  './data/train/malignant\\542.jpg',
#  './data/train/malignant\\543.jpg',
#  './data/train/malignant\\544.jpg',
#  './data/train/malignant\\545.jpg',
#  './data/train/malignant\\547.jpg',
#  './data/train/malignant\\548.jpg',
#  './data/train/malignant\\549.jpg',
#  './data/train/malignant\\55.jpg',
#  './data/train/malignant\\550.jpg',
#  './data/train/malignant\\551.jpg',
#  './data/train/malignant\\552.jpg',
#  './data/train/malignant\\553.jpg',
#  './data/train/malignant\\555.jpg',
#  './data/train/malignant\\557.jpg',
#  './data/train/malignant\\558.jpg',
#  './data/train/malignant\\559.jpg',
#  './data/train/malignant\\56.jpg',
#  './data/train/malignant\\560.jpg',
#  './data/train/malignant\\561.jpg',
#  './data/train/malignant\\563.jpg',
#  './data/train/malignant\\564.jpg',
#  './data/train/malignant\\565.jpg',
#  './data/train/malignant\\566.jpg',
#  './data/train/malignant\\567.jpg',
#  './data/train/malignant\\569.jpg',
#  './data/train/malignant\\571.jpg',
#  './data/train/malignant\\574.jpg',
#  './data/train/malignant\\576.jpg',
#  './data/train/malignant\\577.jpg',
#  './data/train/malignant\\578.jpg',
#  './data/train/malignant\\579.jpg',
#  './data/train/malignant\\580.jpg',
#  './data/train/malignant\\581.jpg',
#  './data/train/malignant\\582.jpg',
#  './data/train/malignant\\583.jpg',
#  './data/train/malignant\\584.jpg',
#  './data/train/malignant\\585.jpg',
#  './data/train/malignant\\586.jpg',
#  './data/train/malignant\\587.jpg',
#  './data/train/malignant\\588.jpg',
#  './data/train/malignant\\589.jpg',
#  './data/train/malignant\\59.jpg',
#  './data/train/malignant\\591.jpg',
#  './data/train/malignant\\594.jpg',
#  './data/train/malignant\\595.jpg',
#  './data/train/malignant\\597.jpg',
#  './data/train/malignant\\598.jpg',
#  './data/train/malignant\\599.jpg',
#  './data/train/malignant\\6.jpg',
#  './data/train/malignant\\60.jpg',
#  './data/train/malignant\\600.jpg',
#  './data/train/malignant\\601.jpg',
#  './data/train/malignant\\604.jpg',
#  './data/train/malignant\\605.jpg',
#  './data/train/malignant\\606.jpg',
#  './data/train/malignant\\607.jpg',
#  './data/train/malignant\\608.jpg',
#  './data/train/malignant\\609.jpg',
#  './data/train/malignant\\61.jpg',
#  './data/train/malignant\\610.jpg',
#  './data/train/malignant\\611.jpg',
#  './data/train/malignant\\612.jpg',
#  './data/train/malignant\\613.jpg',
#  './data/train/malignant\\616.jpg',
#  './data/train/malignant\\617.jpg',
#  './data/train/malignant\\618.jpg',
#  './data/train/malignant\\620.jpg',
#  './data/train/malignant\\621.jpg',
#  './data/train/malignant\\622.jpg',
#  './data/train/malignant\\623.jpg',
#  './data/train/malignant\\624.jpg',
#  './data/train/malignant\\625.jpg',
#  './data/train/malignant\\626.jpg',
#  './data/train/malignant\\627.jpg',
#  './data/train/malignant\\629.jpg',
#  './data/train/malignant\\63.jpg',
#  './data/train/malignant\\630.jpg',
#  './data/train/malignant\\631.jpg',
#  './data/train/malignant\\632.jpg',
#  './data/train/malignant\\633.jpg',
#  './data/train/malignant\\634.jpg',
#  './data/train/malignant\\635.jpg',
#  './data/train/malignant\\636.jpg',
#  './data/train/malignant\\637.jpg',
#  './data/train/malignant\\639.jpg',
#  './data/train/malignant\\64.jpg',
#  './data/train/malignant\\640.jpg',
#  './data/train/malignant\\642.jpg',
#  './data/train/malignant\\644.jpg',
#  './data/train/malignant\\645.jpg',
#  './data/train/malignant\\646.jpg',
#  './data/train/malignant\\647.jpg',
#  './data/train/malignant\\648.jpg',
#  './data/train/malignant\\649.jpg',
#  './data/train/malignant\\650.jpg',
#  './data/train/malignant\\651.jpg',
#  './data/train/malignant\\652.jpg',
#  './data/train/malignant\\654.jpg',
#  './data/train/malignant\\655.jpg',
#  './data/train/malignant\\656.jpg',
#  './data/train/malignant\\657.jpg',
#  './data/train/malignant\\659.jpg',
#  './data/train/malignant\\661.jpg',
#  './data/train/malignant\\662.jpg',
#  './data/train/malignant\\663.jpg',
#  './data/train/malignant\\664.jpg',
#  './data/train/malignant\\665.jpg',
#  './data/train/malignant\\666.jpg',
#  './data/train/malignant\\668.jpg',
#  './data/train/malignant\\669.jpg',
#  './data/train/malignant\\67.jpg',
#  './data/train/malignant\\671.jpg',
#  './data/train/malignant\\672.jpg',
#  './data/train/malignant\\673.jpg',
#  './data/train/malignant\\675.jpg',
#  './data/train/malignant\\676.jpg',
#  './data/train/malignant\\677.jpg',
#  './data/train/malignant\\678.jpg',
#  './data/train/malignant\\680.jpg',
#  './data/train/malignant\\681.jpg',
#  './data/train/malignant\\682.jpg',
#  './data/train/malignant\\683.jpg',
#  './data/train/malignant\\684.jpg',
#  './data/train/malignant\\685.jpg',
#  './data/train/malignant\\687.jpg',
#  './data/train/malignant\\688.jpg',
#  './data/train/malignant\\689.jpg',
#  './data/train/malignant\\69.jpg',
#  './data/train/malignant\\690.jpg',
#  './data/train/malignant\\691.jpg',
#  './data/train/malignant\\692.jpg',
#  './data/train/malignant\\693.jpg',
#  './data/train/malignant\\695.jpg',
#  './data/train/malignant\\697.jpg',
#  './data/train/malignant\\698.jpg',
#  './data/train/malignant\\699.jpg',
#  './data/train/malignant\\7.jpg',
#  './data/train/malignant\\70.jpg',
#  './data/train/malignant\\700.jpg',
#  './data/train/malignant\\701.jpg',
#  './data/train/malignant\\702.jpg',
#  './data/train/malignant\\703.jpg',
#  './data/train/malignant\\704.jpg',
#  './data/train/malignant\\705.jpg',
#  './data/train/malignant\\707.jpg',
#  './data/train/malignant\\708.jpg',
#  './data/train/malignant\\71.jpg',
#  './data/train/malignant\\710.jpg',
#  './data/train/malignant\\711.jpg',
#  './data/train/malignant\\712.jpg',
#  './data/train/malignant\\714.jpg',
#  './data/train/malignant\\715.jpg',
#  './data/train/malignant\\716.jpg',
#  './data/train/malignant\\717.jpg',
#  './data/train/malignant\\718.jpg',
#  './data/train/malignant\\719.jpg',
#  './data/train/malignant\\72.jpg',
#  './data/train/malignant\\720.jpg',
#  './data/train/malignant\\721.jpg',
#  './data/train/malignant\\722.jpg',
#  './data/train/malignant\\723.jpg',
#  './data/train/malignant\\724.jpg',
#  './data/train/malignant\\725.jpg',
#  './data/train/malignant\\726.jpg',
#  './data/train/malignant\\727.jpg',
#  './data/train/malignant\\728.jpg',
#  './data/train/malignant\\729.jpg',
#  './data/train/malignant\\730.jpg',
#  './data/train/malignant\\731.jpg',
#  './data/train/malignant\\732.jpg',
#  './data/train/malignant\\733.jpg',
#  './data/train/malignant\\734.jpg',
#  './data/train/malignant\\736.jpg',
#  './data/train/malignant\\737.jpg',
#  './data/train/malignant\\738.jpg',
#  './data/train/malignant\\740.jpg',
#  './data/train/malignant\\741.jpg',
#  './data/train/malignant\\742.jpg',
#  './data/train/malignant\\743.jpg',
#  './data/train/malignant\\745.jpg',
#  './data/train/malignant\\746.jpg',
#  './data/train/malignant\\748.jpg',
#  './data/train/malignant\\75.jpg',
#  './data/train/malignant\\750.jpg',
#  './data/train/malignant\\751.jpg',
#  './data/train/malignant\\752.jpg',
#  './data/train/malignant\\753.jpg',
#  './data/train/malignant\\754.jpg',
#  './data/train/malignant\\755.jpg',
#  './data/train/malignant\\756.jpg',
#  './data/train/malignant\\758.jpg',
#  './data/train/malignant\\76.jpg',
#  './data/train/malignant\\760.jpg',
#  './data/train/malignant\\761.jpg',
#  './data/train/malignant\\764.jpg',
#  './data/train/malignant\\765.jpg',
#  './data/train/malignant\\766.jpg',
#  './data/train/malignant\\768.jpg',
#  './data/train/malignant\\769.jpg',
#  './data/train/malignant\\77.jpg',
#  './data/train/malignant\\770.jpg',
#  './data/train/malignant\\772.jpg',
#  './data/train/malignant\\774.jpg',
#  './data/train/malignant\\775.jpg',
#  './data/train/malignant\\777.jpg',
#  './data/train/malignant\\779.jpg',
#  './data/train/malignant\\78.jpg',
#  './data/train/malignant\\780.jpg',
#  './data/train/malignant\\781.jpg',
#  ...]

# %%
#https://www.unioviedo.es/compnum/labs/PYTHON/intro_image.html

def load_images(paths):
    tmp = []
    for path in paths:
        tmp.append(imread(path))
    return tmp
    
def plot_any(arr, title = ''):
    plt.figure(figsize = (15, 25))
    for i in range(len(arr)):
        plt.subplot(1,len(arr),i + 1)
        plt.title(title)
        plt.imshow(arr[i]);
def d2Kmeans(img, k):
    return KMeans(n_jobs=-1, 
                  random_state=1, 
                  n_clusters = k, 
                  init='k-means++'
    ).fit(img.reshape((-1,1))).labels_.reshape(img.shape)

def mean_filter(image, raio_disk):
    return rank.mean_percentile(image, selem = disk(raio_disk))

def binary(image):
    return image > threshold_otsu(image)

# %%
#data train
mal = load_images(mal_images)
ben = load_images(ben_images)

#data test
mal_test = load_images(mal_images_test)
ben_test = load_images(ben_images_test)

mal_1 = load_images(mal_images_1)
ben_1 = load_images(ben_images_1)

# %%
plot_any(mal_1)
plot_any(ben_1)

# %%
img_selected = mal[0]

# %%
len(img_selected[0][0])
# Out:
# 3

# %%
len(mal)
# Out:
# 1197

# %%
plt.imshow(img_selected,cmap='hot')

# %%
#Train
mal_arr = np.array(mal)
ben_arr = np.array(ben)

mal_arr_test = np.array(mal_test)
ben_arr_test = np.array(ben_test)

# %%
#On creer les array labels 1 pour mal et 0 pour ben : (ben La bénignité est une condition inoffensive à long terme)
#Data train
target_mal = np.ones(len(mal_arr))       #1 pour malign
target_ben = np.ones(len(ben_arr)) - 1    #0 pour benign
#Data test
target_mal_test = np.ones(len(mal_arr_test))       #1 pour malign
target_ben_test = np.ones(len(ben_arr_test)) - 1    #0 pour benign

# %%
#Data train
X_train = np.concatenate((mal_arr,ben_arr),axis=0)
y_train = np.concatenate((target_mal,target_ben),axis=0)

#Data test
X_test = np.concatenate((mal_arr_test,ben_arr_test),axis=0)
y_test = np.concatenate((target_mal_test,target_ben_test),axis=0)

# %%
len(X_train)
# Out:
# 2637

# %%
X_train.shape
# Out:
# (2637, 224, 224, 3)

# %%
len(y_train)
# Out:
# 2637

# %%
y_train
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %%
X_test.shape
# Out:
# (660, 224, 224, 3)

# %%
y_test.shape
# Out:
# (660,)

# %% [markdown]
# # Training

# %% [markdown]
# <b>1 - Using SVM without filter</b>

# %%
from PIL import Image
test =  Image.open("2.jpg")
test = test.resize((28, 28))
test = np.array(test)
test = test.flatten()

# %%
test
# Out:
# array([38, 44, 51, ..., 27, 29, 26], dtype=uint8)

# %%
targ = np.array(1)

# %%
def flatten_all(features):
    imgs = []
    for i in features:
        imgs.append(i.flatten())
    return np.array(imgs)

# %%
imgs = flatten_all(X_train)

# %%
imgs
# Out:
# array([[162, 136, 113, ..., 167, 161, 147],
#        [ 55,  23,  26, ...,  30,  18,  18],
#        [220, 206, 205, ..., 250, 227, 213],
#        ...,
#        [144,  47,  58, ...,  79,  28,  35],
#        [186, 152, 166, ..., 177, 141, 153],
#        [217, 125, 138, ..., 202, 131, 137]], dtype=uint8)

# %%
#Import svm model
from sklearn import svm

#SVM classifier
clf = svm.SVC(kernel='linear') #kernel linear

#Training
clf.fit(imgs,y_train)
# Out:
# SVC(kernel='linear')

# %%
imgs_test = flatten_all(X_test)

# %%
y_pred =clf.predict(imgs_test)

# %%
#Calcul de la precision
from sklearn import metrics
print("Accuracy:", metrics.accuracy_score(y_test,y_pred) )
# Out:
# Accuracy: 0.7818181818181819

# %%
#Pourcentage de tuples positifs est étiqueté comme tel
print("Precision:",metrics.precision_score(y_test, y_pred))
# Out:
# Precision: 0.7805755395683454

# %%
# Model Recall: Pourcentage de tuples positifs est étiqueté comme tel
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Recall: 0.7233333333333334

# %%
metrics.confusion_matrix(y_test, y_pred)
# Out:
# array([[299,  61],
#        [ 83, 217]], dtype=int64)

# %% [markdown]
# <b>2 -Random forest algorithm without filter</b>

# %%
#Import random forest classifier
from sklearn.ensemble import RandomForestClassifier

#training random Forest
rf_model=RandomForestClassifier(n_estimators=100)
#Fit
rf_model.fit(imgs,y_train)
# Out:
# RandomForestClassifier()

# %%
y_rf_pred = rf_model.predict(imgs_test)

# %%
#Calcul de la precision
from sklearn import metrics
print("Accuracy:", metrics.accuracy_score(y_test,y_rf_pred) )
# Out:
# Accuracy: 0.8151515151515152

# %%
#Pourcentage de tuples positifs est étiqueté comme tel
print("Precision:",metrics.precision_score(y_test, y_rf_pred))
# Out:
# Precision: 0.7633136094674556

# %%
# Model Recall: Pourcentage de tuples positifs est étiqueté comme tel
print("Recall:",metrics.recall_score(y_test, y_rf_pred))
# Out:
# Recall: 0.86

# %% [markdown]
# <b>KNN without filter</b>

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier ( n_neighbors =5)
model_knn.fit(imgs,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_knn_pred = model_knn.predict(imgs_test)

# %%
#Calcul de la precision
from sklearn import metrics
print("Accuracy:", metrics.accuracy_score(y_test,y_knn_pred) )
# Out:
# Accuracy: 0.7484848484848485

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import learning_curve

# %%
def evaluate(model):
    model.fit(X_train,y_train)
    ypred= model.predict(X_test)
    
    print(confusion_matrix(y_test,ypred))
    print(classification_report(y_test,ypred))
